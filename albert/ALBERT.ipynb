# %% [markdown]
# <a href="https://colab.research.google.com/github/xf05888/google-research/blob/master/ALBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/google-research/google-research
# Out:
# Cloning into 'google-research'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 8817 (delta 8), reused 23 (delta 1), pack-reused 8787
# Receiving objects: 100% (8817/8817), 203.66 MiB | 30.55 MiB/s, done.
# Resolving deltas: 100% (2623/2623), done.
# Checking out files: 100% (4681/4681), done.

# %%
! apt install python3-virtualenv virtualenv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package python3-sentencepiece

# %%
# !pip3 install tensorflow_hub sentencepiece
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/14/3d/efb655a670b98f62ec32d66954e1109f403db4d937c50d779a75b9763a29/sentencepiece-0.1.83-cp36-cp36m-manylinux1_x86_64.whl
# ...

# %%
import tensorflow_hub as hub
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
! cd google-research/albert

# %%
# !ls
# Out:
# google-research  sample_data

# %%
# !cd  google-research/albert && ls
# Out:
# classifier_utils.py	    modeling_test.py		  run.sh
# create_pretraining_data.py  optimization.py		  run_small_test.py
# export_to_tfhub.py	    optimization_test.py	  run_squad_sp.py
# gitignore		    README.md			  squad_utils.py
# __init__.py		    requirements.txt		  tokenization.py
# lamb_optimizer.py	    run_classifier_sp.py	  tokenization_test.py
# leakr_badwords.dic	    run_classifier_with_tfhub.py
# modeling.py		    run_pretraining.py

# %%
# !cd google-research && bash albert/run.sh
# Out:
# + virtualenv -p python3 .
# Already using interpreter /usr/bin/python3
# Using base prefix '/usr'
# New python executable in /content/google-research/bin/python3
# Also creating executable in /content/google-research/bin/python
# Installing setuptools, pkg_resources, pip, wheel...done.
# + source ./bin/activate
# ++ deactivate nondestructive
# ++ unset -f pydoc
# ++ '[' -z '' ']'
# ++ '[' -z '' ']'
# ++ '[' -n /bin/bash ']'
# ++ hash -r
# ++ '[' -z '' ']'
# ++ unset VIRTUAL_ENV
# ++ '[' '!' nondestructive = nondestructive ']'
# ++ VIRTUAL_ENV=/content/google-research
# ++ export VIRTUAL_ENV
# ++ _OLD_VIRTUAL_PATH=/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin
# ++ PATH=/content/google-research/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin
# ++ export PATH
# ...

# %%
# !mv google-research/albert albert

# %%
from albert import *

# %%
from albert.run_classifier_with_tfhub import *

# %%
albert_module = hub.Module(
    "https://tfhub.dev/google/albert_xxlarge/2",
    trainable=True)
albert_inputs = dict(
    input_ids=input_ids,
    input_mask=input_mask,
    segment_ids=segment_ids)
albert_outputs = albert_module(albert_inputs, signature="tokens", as_dict=True)
pooled_output = albert_outputs["pooled_output"]
sequence_output = albert_outputs["sequence_output"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-11e527ce27c0> in <module>()
#       3     trainable=True)
#       4 albert_inputs = dict(
# ----> 5     input_ids=input_ids,
#       6     input_mask=input_mask,
#       7     segment_ids=segment_ids)
#
# NameError: name 'input_ids' is not defined
